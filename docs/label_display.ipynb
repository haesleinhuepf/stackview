# %%
import stackview

# %%
labels = [[0,1],[2,3]]

stackview.insight(labels)
# Out:
# StackViewNDArray([[0, 1],
#                   [2, 3]])

# %%
labels = [[4,1],[2,3]]

stackview.insight(labels)
# Out:
# StackViewNDArray([[4, 1],
#                   [2, 3]])

# %%
labels = [[5.,1.],[2.,3.]]

stackview.insight(labels)
# Out:
# StackViewNDArray([[5., 1.],
#                   [2., 3.]])
