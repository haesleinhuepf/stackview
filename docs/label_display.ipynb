# %%
import stackview

# %%
labels = [[0,1],[2,3]]

stackview.insight(labels)
# Out:
# [[0 1]
#  [2 3]]

# %%
labels = [[4,1],[2,3]]

stackview.insight(labels)
# Out:
# [[4 1]
#  [2 3]]

# %%
labels = [[5,1],[2,3]]

stackview.insight(labels)
# Out:
# [[5 1]
#  [2 3]]

# %%
labels = [[4,1],[2,-3]]

stackview.insight(labels)
# Out:
# [[ 4  1]
#  [ 2 -3]]
