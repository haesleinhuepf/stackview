# %%
import scipy.io
import numpy as np
data = scipy.io.loadmat('HEMO1_results_Oct24_1031am.mat')
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'medi_chi_pos', 'medi_chi_neg', 'lin_chi_pos', 'lin_chi_neg', 'nonlin_chi_pos', 'nonlin_chi_neg'])

# %%
img = np.concatenate([data['medi_chi_pos'], data['lin_chi_pos'], data['nonlin_chi_pos']], axis=0)
img.shape
# Out:
# (1536, 512, 64)

# %%
from vis import vis

vis(-img, display_min=0, display_max=0.2)

# %%
comp = data['medi_chi_pos'] + 1j * data['lin_chi_pos']

# %%
vis(comp, display_min=0, display_max=0.2)
